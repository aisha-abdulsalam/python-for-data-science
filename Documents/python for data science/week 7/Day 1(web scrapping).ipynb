# %%
pip install beautifulsoup4 lxml html5lib pandas
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\abdul\anaconda\lib\site-packages (4.12.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: lxml in c:\users\abdul\anaconda\lib\site-packages (4.9.2)
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#                                               0.0/112.2 kB ? eta -:--:--
#      ----------                              30.7/112.2 kB 1.4 MB/s eta 0:00:01
#      -------------                         41.0/112.2 kB 330.3 kB/s eta 0:00:01
#      ------------------------------        92.2/112.2 kB 525.1 kB/s eta 0:00:01
#      ------------------------------        92.2/112.2 kB 525.1 kB/s eta 0:00:01
#      ------------------------------------ 112.2/112.2 kB 435.6 kB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\abdul\anaconda\lib\site-packages (1.5.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\abdul\anaconda\lib\site-packages (from beautifulsoup4) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\abdul\anaconda\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\abdul\anaconda\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\abdul\anaconda\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abdul\anaconda\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\abdul\anaconda\lib\site-packages (from pandas) (1.24.3)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1

# %%
from bs4 import BeautifulSoup as bs
import pandas as pd 
import requests

url = 'https://jiji.ng/'
page = requests.get(url)
#print(page)
soup = bs(page.content, 'html5lib')
#print(soup.prettify())
table = soup.find('div', attrs={'class': "h-dflex h-flex-wrap h-mh--7 h-mb--15"}) #attrs is short for attributes
#print(table.prettify())
rows = table.findAll('div', attrs={'class': "b-listing-cards__item"})
#print(rows[0])
items = []
df = pd.DataFrame(columns=['title', 'price', 'imageCount', 'link'])   #df stands for data frame
for row in rows:
    item = {}
    item['title'] = row.find('div', attrs={'class': 'b-trending-card__title'}).text.replace("\n        ", "").replace("\n      ", "")
    item['price'] = row.find('div', attrs={'class': 'b-trending-card__price'}).text.replace("\n        ", "").replace("\n      ", "")
    item['imageCount'] = row.find('div', attrs={'class': 'b-trending-card__counter'}).text.replace("\n        ", "").replace("\n      ", "")
    item['link'] = row.a['href']
    items.append(item)
    df = df.append(item, ignore_index=True)

#print(items)
df.to_csv('jiji_trending_adds.csv')
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15616\860605190.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
